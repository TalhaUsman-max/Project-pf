# %% [markdown]
# ### Name:Talha Usman
#
# ####  Roll No:SU92-BSAIM-F24-064
#
# ### Progamming Fundamental Project

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('project.csv')
df
# Out:
#          State         Region  iPhone Sales (in million units)  \
# 0    Chongqing  Greater China                                7
# 1      Germany         Europe                                8
# 2           UK         Europe                                5
# 3     Shanghai  Greater China                                7
# 4     Thailand   Rest of Asia                               16
# ..         ...            ...                              ...
# 995     Mexico  Rest of World                               29
# 996      Texas  North America                               27
# 997    Germany         Europe                               25
# 998   Shenzhen  Greater China                               15
# 999   Shanghai  Greater China                               26
#
#      iPad Sales (in million units)  Mac Sales (in million units)  \
# 0                                6                             1
# 1                               14                             7
# ...

# %%
df.head(5)
# Out:
#        State         Region  iPhone Sales (in million units)  \
# 0  Chongqing  Greater China                                7
# 1    Germany         Europe                                8
# 2         UK         Europe                                5
# 3   Shanghai  Greater China                                7
# 4   Thailand   Rest of Asia                               16
#
#    iPad Sales (in million units)  Mac Sales (in million units)  \
# 0                              6                             1
# 1                             14                             7
# 2                             14                             8
# 3                              7                             9
# 4                              8                             6
#
#    Wearables (in million units)  Services Revenue (in billion $)
# 0                             5                               15
# 1                             7                               10
# ...

# %%
df.tail()
# Out:
#         State         Region  iPhone Sales (in million units)  \
# 995    Mexico  Rest of World                               29
# 996     Texas  North America                               27
# 997   Germany         Europe                               25
# 998  Shenzhen  Greater China                               15
# 999  Shanghai  Greater China                               26
#
#      iPad Sales (in million units)  Mac Sales (in million units)  \
# 995                             10                             7
# 996                             12                             8
# 997                              7                             7
# 998                              8                             8
# 999                              4                             3
#
#      Wearables (in million units)  Services Revenue (in billion $)
# 995                             9                               18
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 7 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   State                            1000 non-null   object
#  1   Region                           1000 non-null   object
#  2   iPhone Sales (in million units)  1000 non-null   int64
#  3   iPad Sales (in million units)    1000 non-null   int64
#  4   Mac Sales (in million units)     1000 non-null   int64
#  5   Wearables (in million units)     1000 non-null   int64
#  6   Services Revenue (in billion $)  1000 non-null   int64
# dtypes: int64(5), object(2)
# memory usage: 54.8+ KB

# %%
df.sample(5)
# Out:
#             State         Region  iPhone Sales (in million units)  \
# 356         Texas  North America                               19
# 873  South Africa  Rest of World                                8
# 796         Japan   Rest of Asia                                7
# 417     Hong Kong  Greater China                               25
# 136     Australia  Rest of World                               10
#
#      iPad Sales (in million units)  Mac Sales (in million units)  \
# 356                              5                             4
# 873                              8                             5
# 796                              7                             8
# 417                             12                             2
# 136                              4                             8
#
#      Wearables (in million units)  Services Revenue (in billion $)
# 356                             3                               19
# ...

# %%
df.describe()
# Out:
#        iPhone Sales (in million units)  iPad Sales (in million units)  \
# count                      1000.000000                    1000.000000
# mean                         16.942000                       8.051000
# std                           7.164214                       3.735017
# min                           5.000000                       2.000000
# 25%                          11.000000                       5.000000
# 50%                          17.000000                       8.000000
# 75%                          23.000000                      11.000000
# max                          29.000000                      14.000000
#
#        Mac Sales (in million units)  Wearables (in million units)  \
# count                   1000.000000                   1000.000000
# mean                       5.057000                      6.436000
# std                        2.493184                      2.940842
# min                        1.000000                      2.000000
# ...

# %%
df.describe(include="all")
# Out:
#             State         Region  iPhone Sales (in million units)  \
# count        1000           1000                      1000.000000
# unique         25              5                              NaN
# top     Hong Kong  Rest of World                              NaN
# freq           50            221                              NaN
# mean          NaN            NaN                        16.942000
# std           NaN            NaN                         7.164214
# min           NaN            NaN                         5.000000
# 25%           NaN            NaN                        11.000000
# 50%           NaN            NaN                        17.000000
# 75%           NaN            NaN                        23.000000
# max           NaN            NaN                        29.000000
#
#         iPad Sales (in million units)  Mac Sales (in million units)  \
# count                     1000.000000                   1000.000000
# ...

# %%
df.drop_duplicates()
# Out:
#          State         Region  iPhone Sales (in million units)  \
# 0    Chongqing  Greater China                                7
# 1      Germany         Europe                                8
# 2           UK         Europe                                5
# 3     Shanghai  Greater China                                7
# 4     Thailand   Rest of Asia                               16
# ..         ...            ...                              ...
# 995     Mexico  Rest of World                               29
# 996      Texas  North America                               27
# 997    Germany         Europe                               25
# 998   Shenzhen  Greater China                               15
# 999   Shanghai  Greater China                               26
#
#      iPad Sales (in million units)  Mac Sales (in million units)  \
# 0                                6                             1
# 1                               14                             7
# ...

# %%
a=df["iPad Sales (in million units)"]
a
# Out:
# 0       6
# 1      14
# 2      14
# 3       7
# 4       8
#        ..
# 995    10
# 996    12
# 997     7
# 998     8
# 999     4
# Name: iPad Sales (in million units), Length: 1000, dtype: int64

# %%
b=df[["State","Region","iPhone Sales (in million units)"]]
b
# Out:
#          State         Region  iPhone Sales (in million units)
# 0    Chongqing  Greater China                                7
# 1      Germany         Europe                                8
# 2           UK         Europe                                5
# 3     Shanghai  Greater China                                7
# 4     Thailand   Rest of Asia                               16
# ..         ...            ...                              ...
# 995     Mexico  Rest of World                               29
# 996      Texas  North America                               27
# 997    Germany         Europe                               25
# 998   Shenzhen  Greater China                               15
# 999   Shanghai  Greater China                               26
#
# [1000 rows x 3 columns]

# %%
df[["Wearables (in million units)"]]
# Out:
#      Wearables (in million units)
# 0                               5
# 1                               7
# 2                               8
# 3                               2
# 4                               3
# ..                            ...
# 995                             9
# 996                             4
# 997                             6
# 998                             8
# 999                             5
#
# [1000 rows x 1 columns]

# %%
df["Wearables (in million units)"].mean()
# Out:
# np.float64(6.436)

# %%
df["iPad Sales (in million units)"].mode()
# Out:
# 0     9
# 1    11
# Name: iPad Sales (in million units), dtype: int64

# %%
df["Mac Sales (in million units)"].median()
# Out:
# np.float64(5.0)

# %%
df[["Mac Sales (in million units)","Wearables (in million units)"]].sum()
# Out:
# Mac Sales (in million units)    5057
# Wearables (in million units)    6436
# dtype: int64

# %%
df.count()
# Out:
# State                              1000
# Region                             1000
# iPhone Sales (in million units)    1000
# iPad Sales (in million units)      1000
# Mac Sales (in million units)       1000
# Wearables (in million units)       1000
# Services Revenue (in billion $)    1000
# dtype: int64

# %%
df['iPad Sales (in million units)'].value_counts().plot(kind="line")
# Out:
# <Axes: xlabel='iPad Sales (in million units)'>

# %%
df['iPhone Sales (in million units)'].value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='iPhone Sales (in million units)'>

# %%
df['iPhone Sales (in million units)'].value_counts().plot(kind="barh")
# Out:
# <Axes: ylabel='iPhone Sales (in million units)'>

# %%
df["Mac Sales (in million units)"].value_counts().plot(kind='hist')
plt.xlabel('Category')
plt.ylabel('Frequency')
plt.title("hist graph of Mac sales")
# Out:
# Text(0.5, 1.0, 'hist graph of Mac sales')

# %%
df["iPad Sales (in million units)"].value_counts().plot(kind='box')
# Out:
# <Axes: >

# %%
df['iPhone Sales (in million units)'].value_counts().plot(kind='area')
# Out:
# <Axes: xlabel='iPhone Sales (in million units)'>

# %%
df['iPhone Sales (in million units)'].value_counts().plot(kind='pie')
# Out:
# <Axes: ylabel='count'>

# %%
df['Mac Sales (in million units)'].value_counts().plot(kind='area')
# Out:
# <Axes: xlabel='Mac Sales (in million units)'>

# %%
df.plot(kind="scatter",x="iPhone Sales (in million units)",y="Mac Sales (in million units)")
plt.title("scatter graph")
# Out:
# Text(0.5, 1.0, 'scatter graph')

# %%
df.plot(kind="scatter",x="iPad Sales (in million units)",y="Wearables (in million units)")
plt.show()

# %%
df.isnull()
# Out:
#      State  Region  iPhone Sales (in million units)  \
# 0    False   False                            False
# 1    False   False                            False
# 2    False   False                            False
# 3    False   False                            False
# 4    False   False                            False
# ..     ...     ...                              ...
# 995  False   False                            False
# 996  False   False                            False
# 997  False   False                            False
# 998  False   False                            False
# 999  False   False                            False
#
#      iPad Sales (in million units)  Mac Sales (in million units)  \
# 0                            False                         False
# 1                            False                         False
# 2                            False                         False
# 3                            False                         False
# ...

# %%
df.isnull().sum()
# Out:
# State                              0
# Region                             0
# iPhone Sales (in million units)    0
# iPad Sales (in million units)      0
# Mac Sales (in million units)       0
# Wearables (in million units)       0
# Services Revenue (in billion $)    0
# dtype: int64

# %%
df.notnull()
# Out:
#      State  Region  iPhone Sales (in million units)  \
# 0     True    True                             True
# 1     True    True                             True
# 2     True    True                             True
# 3     True    True                             True
# 4     True    True                             True
# ..     ...     ...                              ...
# 995   True    True                             True
# 996   True    True                             True
# 997   True    True                             True
# 998   True    True                             True
# 999   True    True                             True
#
#      iPad Sales (in million units)  Mac Sales (in million units)  \
# 0                             True                          True
# 1                             True                          True
# 2                             True                          True
# 3                             True                          True
# ...

# %%
df["Services Revenue (in billion $)"].fillna(10)
# Out:
# 0      15
# 1      10
# 2      19
# 3       6
# 4      13
#        ..
# 995    18
# 996     6
# 997    15
# 998    15
# 999    14
# Name: Services Revenue (in billion $), Length: 1000, dtype: int64

# %%
df["Services Revenue (in billion $)"].fillna(10,inplace=True)
df
# Out:
# C:\Users\Talha Usman\AppData\Local\Temp\ipykernel_11728\3503098243.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Services Revenue (in billion $)"].fillna(10,inplace=True)
#          State         Region  iPhone Sales (in million units)  \
# 0    Chongqing  Greater China                                7
# 1      Germany         Europe                                8
# 2           UK         Europe                                5
# 3     Shanghai  Greater China                                7
# ...

# %%
df["iPhone Sales (in million units)"].isnull()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 995    False
# 996    False
# 997    False
# 998    False
# 999    False
# Name: iPhone Sales (in million units), Length: 1000, dtype: bool

# %%
df.dropna()
# Out:
#          State         Region  iPhone Sales (in million units)  \
# 0    Chongqing  Greater China                                7
# 1      Germany         Europe                                8
# 2           UK         Europe                                5
# 3     Shanghai  Greater China                                7
# 4     Thailand   Rest of Asia                               16
# ..         ...            ...                              ...
# 995     Mexico  Rest of World                               29
# 996      Texas  North America                               27
# 997    Germany         Europe                               25
# 998   Shenzhen  Greater China                               15
# 999   Shanghai  Greater China                               26
#
#      iPad Sales (in million units)  Mac Sales (in million units)  \
# 0                                6                             1
# 1                               14                             7
# ...

# %%
df.loc[[2,5,8,18,60]]
# Out:
#           State         Region  iPhone Sales (in million units)  \
# 2            UK         Europe                                5
# 5     Chongqing  Greater China                               12
# 8        Mexico  Rest of World                               20
# 18     Shanghai  Greater China                               14
# 60  South Korea   Rest of Asia                               15
#
#     iPad Sales (in million units)  Mac Sales (in million units)  \
# 2                              14                             8
# 5                              10                             9
# 8                               6                             4
# 18                              4                             8
# 60                             12                             4
#
#     Wearables (in million units)  Services Revenue (in billion $)
# 2                              8                               19
# ...

# %%
df.iloc[[2,23,345,478,579,789,12]]
# Out:
#             State         Region  iPhone Sales (in million units)  \
# 2              UK         Europe                                5
# 23          Texas  North America                               24
# 345        France         Europe                               20
# 478         Spain         Europe                               10
# 579       Germany         Europe                               15
# 789  South Africa  Rest of World                                5
# 12      Hong Kong  Greater China                               23
#
#      iPad Sales (in million units)  Mac Sales (in million units)  \
# 2                               14                             8
# 23                               4                             1
# 345                              5                             1
# 478                              4                             3
# 579                              4                             2
# ...

# %%
df.groupby("Region").describe()
# Out:
#               iPhone Sales (in million units)                            \
#                                         count       mean       std  min
# Region
# Europe                                  204.0  16.960784  7.326881  5.0
# Greater China                           219.0  17.164384  7.304040  5.0
# North America                           178.0  17.039326  6.707246  5.0
# Rest of Asia                            178.0  16.893258  7.182438  5.0
# Rest of World                           221.0  16.665158  7.268619  5.0
#
#                                         iPad Sales (in million units)  \
#                  25%   50%    75%   max                         count
# Region
# Europe         10.00  17.0  23.00  29.0                         204.0
# Greater China  11.00  17.0  24.00  29.0                         219.0
# North America  12.00  17.0  22.75  29.0                         178.0
# Rest of Asia   11.25  16.0  23.00  29.0                         178.0
# ...

# %%
df['iPad Sales (in million units)'].value_counts().reset_index()
# Out:
#     iPad Sales (in million units)  count
# 0                               9     89
# 1                              11     89
# 2                              14     88
# 3                               6     87
# 4                               8     83
# 5                               3     83
# 6                               7     74
# 7                               2     73
# 8                               4     71
# 9                              13     69
# 10                             12     67
# 11                             10     64
# 12                              5     63
